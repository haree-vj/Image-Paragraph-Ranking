# %%
import os
os.chdir('D:\\practicum\\practicum code\\visual-semantic-embedding-master')

# %%
import train

# %%
train_model_euronews = train.trainer()
# Out:
# {'grad_clip': 2.0, 'dim': 1024, 'optimizer': 'adam', 'dim_word': 300, 'data': 'euro', 'lrate': 0.0002, 'batch_size': 128, 'encoder': 'gru', 'maxlen_w': 100, 'saveto': 'D:/practicum/kiros data/train/euronews_data.npz', 'max_epochs': 15, 'dim_image': 25088, 'dispFreq': 10, 'decay_c': 0.0, 'margin': 0.2, 'reload_': False, 'validFreq': 100}
# Loading dataset
# Creating dictionary
# Dictionary size: 82484
# Building model
# C:\Users\hareevarshan\Anaconda2\lib\site-packages\theano\scan_module\scan.py:1019: Warning: In the strict mode, all neccessary shared variables must be passed as a part of non_sequences
#   'must be passed as a part of non_sequences', Warning)
# Building f_log_probs... Done
# Building f_cost... Done
# Building sentence encoder
# Building image encoder
# Building f_grad... Building optimizers... Optimization
# Epoch  0
# Epoch  0 Update  10 Cost  203912.75 UD  2.84899997711
# Epoch  0 Update  20 Cost  121212.64 UD  2.28499984741
# Epoch  0 Update  30 Cost  278421.56 UD  2.2349998951
# Minibatch with zero sample under length  100
# Epoch  0 Update  40 Cost  120065.06 UD  2.15200018883
# Epoch  0 Update  50 Cost  152248.69 UD  2.32899999619
# Epoch  0 Update  60 Cost  0.0 UD  0.529000043869
# Seen 1614 samples
# Epoch  1
# Epoch  1 Update  70 Cost  223730.48 UD  1.60800004005
# Epoch  1 Update  80 Cost  423184.9 UD  2.24099993706
# Epoch  1 Update  90 Cost  19158.162 UD  1.71700000763
# Epoch  1 Update  100 Cost  44035.656 UD  1.68000006676
# Computing results...
# Image to text: 1.0, 4.0, 4.5, 136.0
# Text to image: 0.7, 2.4, 5.0, 100.0
# Saving... Done
# Epoch  1 Update  110 Cost  283275.22 UD  2.39100003242
# Minibatch with zero sample under length  100
# Epoch  1 Update  120 Cost  1449.4338 UD  0.524000167847
# Epoch  1 Update  130 Cost  3276.4683 UD  0.721999883652
# Seen 3228 samples
# Epoch  2
# Epoch  2 Update  140 Cost  17108.137 UD  0.684000015259
# Epoch  2 Update  150 Cost  102053.734 UD  1.48000001907
# Epoch  2 Update  160 Cost  160709.78 UD  1.43300008774
# Epoch  2 Update  170 Cost  5906.2734 UD  0.736999988556
# Minibatch with zero sample under length  100
# Epoch  2 Update  180 Cost  9815.999 UD  0.526999950409
# Epoch  2 Update  190 Cost  59905.3 UD  1.82799983025
# Epoch  2 Update  200 Cost  169961.97 UD  1.58700013161
# Computing results...
# Image to text: 0.5, 4.5, 5.5, 142.0
# Text to image: 0.3, 2.1, 4.4, 102.0
# Seen 4842 samples
# Epoch  3
# Epoch  3 Update  210 Cost  214671.92 UD  1.78099989891
# Epoch  3 Update  220 Cost  76502.65 UD  1.65700006485
# Epoch  3 Update  230 Cost  293324.72 UD  2.59800004959
# Epoch  3 Update  240 Cost  278566.66 UD  2.44000005722
# Epoch  3 Update  250 Cost  131287.22 UD  2.07799983025
# Minibatch with zero sample under length  100
# Epoch  3 Update  260 Cost  0.0 UD  0.59299993515
# Epoch  3 Update  270 Cost  280493.66 UD  2.42599987984
# Seen 6456 samples
# Epoch  4
# Epoch  4 Update  280 Cost  20728.463 UD  0.760999917984
# Epoch  4 Update  290 Cost  0.0 UD  0.498999834061
# Epoch  4 Update  300 Cost  58119.53 UD  1.78499984741
# Computing results...
# Image to text: 0.0, 2.0, 4.0, 119.0
# Text to image: 0.5, 2.5, 5.0, 100.0
# Epoch  4 Update  310 Cost  1226.0211 UD  0.696000099182
# Epoch  4 Update  320 Cost  61207.016 UD  2.2429997921
# Epoch  4 Update  330 Cost  23711.207 UD  1.11699986458
# Minibatch with zero sample under length  100
# Epoch  4 Update  340 Cost  63667.85 UD  1.75499987602
# Seen 8070 samples
# Epoch  5
# Epoch  5 Update  350 Cost  35144.582 UD  0.880999803543
# Epoch  5 Update  360 Cost  216069.67 UD  2.08999991417
# Epoch  5 Update  370 Cost  10854.898 UD  0.680999994278
# Minibatch with zero sample under length  100
# Epoch  5 Update  380 Cost  122549.36 UD  1.85400009155
# Epoch  5 Update  390 Cost  58438.816 UD  1.84699988365
# Epoch  5 Update  400 Cost  15581.065 UD  0.885999917984
# Computing results...
# Image to text: 0.5, 2.0, 4.0, 124.0
# Text to image: 0.5, 2.5, 5.1, 100.0
# Epoch  5 Update  410 Cost  119389.484 UD  2.01999998093
# Seen 9684 samples
# Epoch  6
# Epoch  6 Update  420 Cost  20.416096 UD  0.603999853134
# Epoch  6 Update  430 Cost  2935.8093 UD  0.765000104904
# Epoch  6 Update  440 Cost  2154.4565 UD  0.674999952316
# Epoch  6 Update  450 Cost  33327.89 UD  1.66799998283
# Minibatch with zero sample under length  100
# Epoch  6 Update  460 Cost  22365.162 UD  1.34500002861
# Epoch  6 Update  470 Cost  4553.3853 UD  0.890000104904
# Epoch  6 Update  480 Cost  723.95056 UD  0.653000116348
# Seen 11298 samples
# Epoch  7
# Epoch  7 Update  490 Cost  0.0 UD  0.523999929428
# Epoch  7 Update  500 Cost  34245.715 UD  1.34500002861
# Computing results...
# Image to text: 0.0, 2.0, 5.5, 127.0
# Text to image: 0.5, 2.5, 5.0, 101.0
# Epoch  7 Update  510 Cost  29605.871 UD  1.47100019455
# Epoch  7 Update  520 Cost  190480.36 UD  2.61599993706
# Minibatch with zero sample under length  100
# Epoch  7 Update  530 Cost  4922.386 UD  0.676000118256
# Epoch  7 Update  540 Cost  233242.73 UD  2.56100010872
# Epoch  7 Update  550 Cost  24636.598 UD  1.48300004005
# Seen 12912 samples
# Epoch  8
# Epoch  8 Update  560 Cost  123467.11 UD  2.09200000763
# Epoch  8 Update  570 Cost  99666.25 UD  1.53699994087
# Epoch  8 Update  580 Cost  112959.875 UD  1.85400009155
# Epoch  8 Update  590 Cost  82640.28 UD  1.87599992752
# Minibatch with zero sample under length  100
# Epoch  8 Update  600 Cost  141180.89 UD  2.18300008774
# Computing results...
# Image to text: 1.0, 2.5, 6.5, 120.0
# Text to image: 0.6, 3.0, 5.2, 100.0
# Saving... Done
# Epoch  8 Update  610 Cost  205671.2 UD  2.36199998856
# Epoch  8 Update  620 Cost  63742.164 UD  2.25100016594
# Seen 14526 samples
# Epoch  9
# Epoch  9 Update  630 Cost  81201.35 UD  1.93799996376
# Epoch  9 Update  640 Cost  24392.035 UD  1.79799985886
# Minibatch with zero sample under length  100
# Epoch  9 Update  650 Cost  82541.414 UD  2.10899996758
# Epoch  9 Update  660 Cost  3928.5747 UD  0.646000146866
# Epoch  9 Update  670 Cost  18923.793 UD  0.950000047684
# Epoch  9 Update  680 Cost  38580.742 UD  1.66599988937
# Epoch  9 Update  690 Cost  36597.9 UD  1.64200019836
# Seen 16140 samples
# Epoch  10
# Epoch  10 Update  700 Cost  81941.266 UD  1.77399992943
# Computing results...
# Image to text: 0.0, 2.5, 5.5, 101.0
# Text to image: 0.5, 2.6, 5.0, 100.0
# Epoch  10 Update  710 Cost  63614.043 UD  1.90299987793
# Minibatch with zero sample under length  100
# Epoch  10 Update  720 Cost  22911.375 UD  1.46799993515
# Epoch  10 Update  730 Cost  9563.9 UD  1.96999979019
# Epoch  10 Update  740 Cost  51275.746 UD  1.77699995041
# Epoch  10 Update  750 Cost  476.08658 UD  0.681999921799
# Seen 17754 samples
# Epoch  11
# Epoch  11 Update  760 Cost  339207.16 UD  2.98100018501
# Minibatch with zero sample under length  100
# Epoch  11 Update  770 Cost  160016.38 UD  2.66999983788
# Epoch  11 Update  780 Cost  18358.402 UD  1.49199986458
# Epoch  11 Update  790 Cost  0.0 UD  0.513000011444
# Epoch  11 Update  800 Cost  0.0 UD  0.503000020981
# Computing results...
# Image to text: 2.0, 3.0, 5.5, 111.0
# Text to image: 0.5, 2.3, 5.2, 98.0
# Epoch  11 Update  810 Cost  43805.65 UD  2.11599993706
# Epoch  11 Update  820 Cost  2619.188 UD  1.33000016212
# Seen 19368 samples
# Epoch  12
# Epoch  12 Update  830 Cost  0.0 UD  0.513999938965
# Minibatch with zero sample under length  100
# Epoch  12 Update  840 Cost  14879.575 UD  1.36500000954
# Epoch  12 Update  850 Cost  4269.342 UD  1.34500002861
# Epoch  12 Update  860 Cost  14098.322 UD  0.938999891281
# Epoch  12 Update  870 Cost  4735.129 UD  1.62999987602
# Epoch  12 Update  880 Cost  0.0 UD  0.5
# Epoch  12 Update  890 Cost  73319.46 UD  2.41000008583
# Seen 20982 samples
# Epoch  13
# Epoch  13 Update  900 Cost  11.0012665 UD  0.74799990654
# Computing results...
# Image to text: 0.5, 3.5, 6.0, 115.0
# Text to image: 0.7, 2.9, 5.9, 96.0
# Saving... Done
# Epoch  13 Update  910 Cost  34.42626 UD  0.599999904633
# Epoch  13 Update  920 Cost  0.0 UD  0.505999803543
# Epoch  13 Update  930 Cost  4365.366 UD  1.83699989319
# Minibatch with zero sample under length  100
# Epoch  13 Update  940 Cost  156.35867 UD  0.716000080109
# Epoch  13 Update  950 Cost  1394.5435 UD  1.5529999733
# Epoch  13 Update  960 Cost  0.0 UD  0.450999975204
# Seen 22596 samples
# Epoch  14
# Epoch  14 Update  970 Cost  9713.388 UD  2.19999980927
# Epoch  14 Update  980 Cost  17645.723 UD  2.5609998703
# Epoch  14 Update  990 Cost  0.0 UD  0.686000108719
# Minibatch with zero sample under length  100
# Epoch  14 Update  1000 Cost  123.60297 UD  1.85500001907
# Computing results...
# Image to text: 1.5, 5.0, 10.0, 118.0
# Text to image: 1.0, 3.5, 5.4, 95.0
# Saving... Done
# Epoch  14 Update  1010 Cost  238.37903 UD  0.884999990463
# Epoch  14 Update  1020 Cost  0.0 UD  0.637000083923
# Epoch  14 Update  1030 Cost  471.8605 UD  1.39699983597
# Seen 24210 samples
