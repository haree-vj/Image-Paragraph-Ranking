# %%
import os
os.chdir('D:\\practicum\\practicum code\\visual-semantic-embedding-master')

# %%
import train

# %%
train_model_f30k = train.trainer()
# Out:
# {'grad_clip': 2.0, 'dim': 1024, 'optimizer': 'adam', 'dim_word': 300, 'data': 'f30k', 'lrate': 0.0002, 'batch_size': 128, 'encoder': 'gru', 'maxlen_w': 100, 'saveto': 'D:/practicum/kiros data/train/f30k.npz', 'max_epochs': 15, 'dim_image': 4096, 'dispFreq': 10, 'decay_c': 0.0, 'margin': 0.2, 'reload_': False, 'validFreq': 100}
# Loading dataset
# Creating dictionary
# Dictionary size: 22962
# Building model
# Building f_log_probs... Done
# Building f_cost... Done
# Building sentence encoder
# Building image encoder
# Building f_grad... Building optimizers... Optimization
# Epoch  0
# Epoch  0 Update  10 Cost  0.32889897 UD  0.318000078201
# Epoch  0 Update  20 Cost  0.0 UD  0.229000091553
# Epoch  0 Update  30 Cost  0.0 UD  0.236999988556
# Epoch  0 Update  40 Cost  4488.7266 UD  2.28699994087
# Epoch  0 Update  50 Cost  3970.9236 UD  1.20000004768
# Epoch  0 Update  60 Cost  43.50242 UD  0.491000175476
# Epoch  0 Update  70 Cost  0.2016997 UD  0.288000106812
# ...
